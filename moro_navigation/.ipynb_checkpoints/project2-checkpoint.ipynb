# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import DotDict
import yaml

# Load the map definition from file
filepath = '../../../moro_simulator' + '/world/maze_map.yaml'
with open(filepath) as f:
    msg = DotDict(yaml.safe_load(f))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b31c50118759> in <module>
# ----> 1 from utils import DotDict
#       2 import yaml
#       3
#       4 # Load the map definition from file
#       5 filepath = '../../../moro_simulator' + '/world/maze_map.yaml'
#
# ModuleNotFoundError: No module named 'utils'

# %%
# %matplotlib notebook

from probabilistic_roadmap import ProbabilisticRoadmap
import matplotlib.pyplot as plt

import numpy as np

# Set random seed to compare different parameters
np.random.seed(45)

prm = ProbabilisticRoadmap(msg)
prm.plot()

for node, coord in enumerate(prm.nodes):
    plt.text(coord[0], coord[1], str(node))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-cf23862c296c> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2
# ----> 3 from probabilistic_roadmap import ProbabilisticRoadmap
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'probabilistic_roadmap'

# %%
from moro_navigation.shortest_path import dynamic_programming
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-bc62ad702e17> in <module>
# ----> 1 from moro_navigation.shortest_path import dynamic_programming
#
# ~/catkin_ws/src/moro_ros/moro_navigation/src/moro_navigation/__init__.py in <module>
#       1 #!/usr/bin/env python
# ----> 2 from probabilistic_roadmap import ProbabilisticRoadmap
#       3 from shortest_path import dijkstra, astar, dynamic_programming
#       4 from path_smoothing import smooth_path
#       5 from path_following import PathFollower
#
# ModuleNotFoundError: No module named 'probabilistic_roadmap'

# %%
path = dynamic_programming(prm.graph, 10, 3)
path
# Out:
# deque([10, 18, 15, 25, 5, 4, 12, 9, 40, 16, 30, 38, 22, 3])

# %%
plt.figure()
prm.plot(path)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
